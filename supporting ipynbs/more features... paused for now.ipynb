# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
from time import sleep
from random import randint
import re
import operator
from functools import reduce
import pickle
import random

# %%
pages = pickle.load(open('second','rb'))

# %%
soup = BeautifulSoup(pages[0].content, "html.parser")

# %%
soup.prettify()
# Out:
# '<!DOCTYPE html>\n<html lang="de">\n <head>\n  <meta content="notranslate" data-react-helmet="true" name="google"/>\n  <meta charset="utf-8" data-react-helmet="true"/>\n  <meta content="width=device-width, initial-scale=1, shrink-to-fit=no, user-scalable=no" data-react-helmet="true" name="viewport"/>\n  <meta content="Einfamilienhaus, Bungalow, Reihenendhaus, Reihenmittelhaus, Doppelhaushälfte, Doppelhaus, Bauernhaus, Herrenhaus, Villa, Burg / Schloss, Finca, Rustico, Zweifamilienhaus kaufen in Sachsen. Einfamilienhäuser zum Kauf findest du bei Immowelt ⇒ Jetzt dank großer Auswahl Wunschimmobilie finden!" data-react-helmet="true" name="description"/>\n  <meta content="noindex" data-react-helmet="true" name="robots"/>\n  <meta content="Einfamilienhaus, Bungalow, Reihenendhaus, Reihenmittelhaus, Doppelhaushälfte, Doppelhaus, Bauernhaus, Herrenhaus, Villa, Burg / Schloss, Finca, Rustico, Zweifamilienhaus kaufen in Sachsen" data-react-helmet="true" property="og:title"/>\n  <meta content=
# ...

# %%
text = str(soup.select('div.SearchList-22b2e a'))
text
# Out:
# '[<a class="mainSection-b22fb noProject-eaed4" href="https://www.immowelt.de/expose/29g4z5q" id="29g4z5q" rel="noreferrer" target="_self"><div class="VisualSection-6b708"><div class="ImmoBooster-e578f"><div class="imageWrapper-8c408"><div class="Image-8cb07 image-b29e9 image-f338a"><svg class="ImagePlaceholder-c9f87 ImagePlaceholder--loading-ca6cd placeholder-a84dd" fill="none" preserveaspectratio="xMidYMin slice" viewbox="0 0 328 224" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M-0.643742 -4.87101L-1.45432 168.931L45.2367 108.439C52.7776 98.7412 67.1905 98.8358 74.7397 108.368L105.821 148.295C112.212 156.33 124.503 156.463 130.911 148.366L204.469 56.1773C211.424 47.4817 224.561 47.2897 231.72 55.8064L328 170.34L328.811 -3.46234C328.929 -9.72487 323.879 -14.7778 317.682 -14.7273L10.6212 -16.0002C4.35864 -16.119 -0.694298 -11.0685 -0.643742 -4.87101ZM116.518 84.3348C134.199 84.1932 148.486 69.9908 148.344 52.3104C148.371 34.5635 134 20.3433 116.32 20.4849C98.6392 2
# ...

# %%
pattern = 'id="\w{7}"'
ids = re.findall(pattern, text)
ids
# Out:
# ['id="29g4z5q"',
#  'id="29dqw5q"',
#  'id="29ul65n"',
#  'id="29us35l"',
#  'id="292ws5k"',
#  'id="29uvq5f"',
#  'id="277e654"',
#  'id="29h2j5q"',
#  'id="29pqt5p"',
#  'id="29tb85p"',
#  'id="297k75p"',
#  'id="29nst5m"',
#  'id="29hhj5m"',
#  'id="29wdh5m"',
#  'id="29z635m"',
#  'id="29wuy5l"',
#  'id="29tyx5l"',
#  'id="29rjk5k"',
#  'id="29qwd5k"',
#  'id="29aj55k"']

# %%
# %%time
ids = []


for i in range(len(pages)):
    parsed = BeautifulSoup(pages[i].content, "html.parser")
    id_info = parsed.select("div.SearchList-22b2e")
    
    for j in range(len(id_info)):
        ids.append(id_info[j].select('div.SearchList-22b2e a'))
        ids_text = str(ids)
        
        pattern = 'id="\w{7}"'
        ids_clean = re.findall(pattern, ids_text)
# Out:
# Wall time: 19min 39s

# %%
ids_clean
# Out:
# ['id="29g4z5q"',
#  'id="29dqw5q"',
#  'id="29ul65n"',
#  'id="29us35l"',
#  'id="292ws5k"',
#  'id="29uvq5f"',
#  'id="277e654"',
#  'id="29h2j5q"',
#  'id="29pqt5p"',
#  'id="29tb85p"',
#  'id="297k75p"',
#  'id="29nst5m"',
#  'id="29hhj5m"',
#  'id="29wdh5m"',
#  'id="29z635m"',
#  'id="29wuy5l"',
#  'id="29tyx5l"',
#  'id="29rjk5k"',
#  'id="29qwd5k"',
#  'id="29aj55k"',
#  'id="29wyx5j"',
#  'id="29nyx5j"',
#  'id="29fuw5j"',
#  'id="29ufh5j"',
#  'id="29hwt5g"',
#  'id="296qh5g"',
#  'id="29j625g"',
#  'id="29qfh5f"',
#  'id="29g2f5f"',
#  'id="293xb5f"',
#  'id="29sjg5e"',
#  'id="2956f5e"',
#  'id="296rb5e"',
#  'id="29e5e5d"',
#  'id="29fac5m"',
#  'id="293kb5c"',
#  'id="29ffa5c"',
#  'id="29q345c"',
#  'id="29jzs5a"',
#  'id="29z9x59"',
#  'id="293zw59"',
#  'id="299fl5k"',
#  'id="295t858"',
#  'id="29v3a57"',
#  'id="29kjt5q"',
#  'id="29ug656"',
#  'id="282rv5z"',
#  'id="28z5q5y"',
#  'id="28wyj5y"',
#  'id="29dzc5q"',
#  'id="284xk5v"',
#  'id="28eba5u"',
# ...

# %%
id = pd.DataFrame(ids_clean)
# Out:
#                  0
# 0     id="29g4z5q"
# 1     id="29dqw5q"
# 2     id="29ul65n"
# 3     id="29us35l"
# 4     id="292ws5k"
# ...            ...
# 9375  id="2fyfk4p"
# 9376  id="2fhkb43"
# 9377  id="2egw34e"
# 9378  id="2eru34e"
# 9379  id="2c2dd4n"
#
# [9380 rows x 1 columns]

# %%
id = [re.sub('id="|"', '', str(w)) for w in ids_clean]
id_dataframe = pd.DataFrame(id)
id_dataframe
len(id)
# Out:
# 9380

# %%
# %%time
# id_houses_soups = []
# all_ = []
# all_nrg = []
# energy = []
# year_built = []
# type_of_house = []
# heating = []

# counter = 0

# for i in id:
#     # send request
#     url = "https://www.immowelt.de/expose/" + i
    
#     if response.status_code == 200:
#         id_houses_soups.append(url)
#     if response.status_code != 200:
#         id_houses_soups.append('NaN')
    
#     response = requests.get(url)
#     print(url, response.status_code)

#     # parse & store html
#     soup = BeautifulSoup(response.content, "html.parser")
    
# #     for m in     
#     try:    
#         all_.append(soup.select('sd-cell-row p'))
# #         energy.append(soup.select('sd-cell-row p')[7].get_text())
# #         year_built.append(soup.select('sd-cell:nth-child(3) > sd-cell-row > sd-cell-col > p:nth-child(2)')[0].get_text())
# #         type_of_house.append(soup.select('p:nth-child(2)')[11].get_text())
# #         heating.append(soup.select('p:nth-child(2)')[13].get_text())
        
#     except:        
# #         energy.append('NaN')
# #         year_built.append('NaN')
# #         type_of_house.append('NaN')
# #         heating.append('NaN')
#         continue
     
#     counter += 1
        
#     # respectful nap:
#     if counter % 10 == 0:
#         wait_time = random.randint(1,2)
#         print("I will sleep for " + str(wait_time) + " second/s.")
#         sleep(wait_time)
# Out:
# https://www.immowelt.de/expose/29g4z5q 404
# https://www.immowelt.de/expose/29dqw5q 200
# https://www.immowelt.de/expose/29ul65n 200
# https://www.immowelt.de/expose/29us35l 200
# https://www.immowelt.de/expose/292ws5k 200
# https://www.immowelt.de/expose/29uvq5f 200
# https://www.immowelt.de/expose/277e654 200
# https://www.immowelt.de/expose/29h2j5q 404
# https://www.immowelt.de/expose/29pqt5p 200
# https://www.immowelt.de/expose/29tb85p 404
# I will sleep for 1 second/s.
# https://www.immowelt.de/expose/297k75p 200
# https://www.immowelt.de/expose/29nst5m 200
# https://www.immowelt.de/expose/29hhj5m 200
# https://www.immowelt.de/expose/29wdh5m 200
# https://www.immowelt.de/expose/29z635m 200
# https://www.immowelt.de/expose/29wuy5l 200
# https://www.immowelt.de/expose/29tyx5l 200
# https://www.immowelt.de/expose/29rjk5k 200
# https://www.immowelt.de/expose/29qwd5k 200
# https://www.immowelt.de/expose/29aj55k 404
# I will sleep for 1 second/s.
# ...

# %%
# import pickle
# pickle.dump(pages, open('infos_from_ids', 'wb'))

# %%
data = pickle.load(open('infos_from_ids','rb'))

# %%
all_[2]
# Out:
# [<p>035 ···</p>,
#  <p _ngcontent-sc212="" class="has-font-75 mt-50 ng-star-inserted">Verhandlungsbasis</p>,
#  <p _ngcontent-sc222="" class="has-font-75 color-grey-500">Kategorie</p>,
#  <p _ngcontent-sc222="">Einfamilienhaus</p>,
#  <p _ngcontent-sc233=""><span _ngcontent-sc233="" class="color-grey-500">Energieausweis:</span> für diesen Gebäudetyp nicht notwendig</p>,
#  <p _ngcontent-sc239="" class="color-grey-500 has-font-75">Energieträger</p>,
#  <p _ngcontent-sc239="">Gas</p>,
#  <p _ngcontent-sc239="" class="color-grey-500 has-font-75">Heizungsart</p>,
#  <p _ngcontent-sc239="">Zentralheizung</p>]

# %%
for i in range(len(all_)):
    all_[i] = [re.sub('<p _ngcontent-sc212="" class="has-font-75 mt-50 ng-star-inserted">', '', str(w)) for w in all_[i]]
    all_[i] = [re.sub('<p _ngcontent-sc222="" class="has-font-75 color-grey-500">', '', str(w)) for w in all_[i]]
    all_[i] = [re.sub('<p _ngcontent-sc2|22="">|33=""><span _ngcontent-sc233="" class="color-grey-500">|</span>| ', '', str(w)) for w in all_[i]]

# %%
all_[2]
# Out:
# ['<p>035···</p>',
#  'Verhandlungsbasis</p>',
#  'Kategorie</p>',
#  'Einfamilienhaus</p>',
#  'Energieausweis:fürdiesenGebäudetypnichtnotwendig</p>',
#  '39=""class="color-grey-500has-font-75">Energieträger</p>',
#  '39="">Gas</p>',
#  '39=""class="color-grey-500has-font-75">Heizungsart</p>',
#  '39="">Zentralheizung</p>']

# %%
# Out:
# [<p>035 ···</p>,
#  <p _ngcontent-sc212="" class="has-font-75 mt-50 ng-star-inserted">Verhandlungsbasis</p>,
#  <p _ngcontent-sc222="" class="has-font-75 color-grey-500">Kategorie</p>,
#  <p _ngcontent-sc222="">Einfamilienhaus</p>,
#  <p _ngcontent-sc233=""><span _ngcontent-sc233="" class="color-grey-500">Energieausweis:</span> für diesen Gebäudetyp nicht notwendig</p>,
#  <p _ngcontent-sc239="" class="color-grey-500 has-font-75">Energieträger</p>,
#  <p _ngcontent-sc239="">Gas</p>,
#  <p _ngcontent-sc239="" class="color-grey-500 has-font-75">Heizungsart</p>,
#  <p _ngcontent-sc239="">Zentralheizung</p>]

# %%
#js_innerBody > div.content_wrapper > main > app-expose > div.relative.mt-250.ng-star-inserted > div.section-grey-100.relative > app-expose-sections > sd-container > sd-row > sd-col.col.col-400-12.col-8

# %%
url5 = 'https://www.immowelt.de/expose/29dqw5q'
response = requests.get(url5)
response.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(response.content, "html.parser")

# %%
print(soup.prettify())
# Out:
# <html class="immowelt" lang="de">
#  <head>
#   <base href="/"/>
#   <meta charset="utf-8"/>
#   <title>
#    SELTENER GLÜCKSFALL! Vielseitig Talentierte Doppelhaushälfte mit Charme und Atmosphäre in beliebter Eulenbergsiedlung | Doppelhaushälfte Markkleeberg (29DQW5Q) | immowelt
#   </title>
#   <meta content="index, follow" name="robots"/>
#   <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
#   <meta content="article" property="og:type"/>
#   <meta content="summary" name="twitter:card"/>
#   <style>
# ...

# %%
soup.select('sd-cell-row p')#[7].get_text() # Baujahr
# Out:
# [<p>034 ···</p>,
#  <p _ngcontent-sc222="" class="has-font-75 color-grey-500">Kategorie</p>,
#  <p _ngcontent-sc222="">Doppelhaushälfte</p>,
#  <p class="color-grey-500 has-font-75">Energieausweistyp</p>,
#  <p>Bedarfsausweis</p>,
#  <p class="color-grey-500 has-font-75">Gebäudetyp</p>,
#  <p>Wohngebäude</p>,
#  <p class="color-grey-500 has-font-75">Baujahr laut Energieausweis</p>,
#  <p>1936</p>,
#  <p class="color-grey-500 has-font-75">Wesentliche Energieträger</p>,
#  <p>FERN</p>,
#  <p class="color-grey-500 has-font-75">Gültigkeit</p>,
#  <p class="datacontent ng-star-inserted"> bis 25.08.2032 </p>,
#  <p class="color-grey-500 has-font-75">Effizienzklasse</p>,
#  <p>H</p>,
#  <p class="color-grey-500 has-font-75">Endenergiebedarf</p>,
#  <p> 262,00 kWh/(m²·a)  </p>,
#  <p _ngcontent-sc239="" class="color-grey-500 has-font-75">Energieträger</p>,
#  <p _ngcontent-sc239="">Fernwärme</p>,
#  <p _ngcontent-sc239="" class="color-grey-500 has-font-75">Heizungsart</p>,
# ...

# %%
soup.select('#js_innerBody > div.content_wrapper > main > app-expose > div.relative.mt-250.ng-star-inserted > div.section-grey-100.relative > app-expose-sections > sd-container > sd-row > sd-col.col.col-400-12.col-8 > div:nth-child(6) > div > app-energy > sd-card p')#[13].get_text() # Energieträger
# Out:
# [<p class="color-grey-500 has-font-75">Energieausweistyp</p>,
#  <p>Bedarfsausweis</p>,
#  <p class="color-grey-500 has-font-75">Gebäudetyp</p>,
#  <p>Wohngebäude</p>,
#  <p class="color-grey-500 has-font-75">Baujahr laut Energieausweis</p>,
#  <p>1936</p>,
#  <p class="color-grey-500 has-font-75">Wesentliche Energieträger</p>,
#  <p>FERN</p>,
#  <p class="color-grey-500 has-font-75">Gültigkeit</p>,
#  <p class="datacontent ng-star-inserted"> bis 25.08.2032 </p>,
#  <p class="color-grey-500 has-font-75">Effizienzklasse</p>,
#  <p>H</p>,
#  <p class="color-grey-500 has-font-75">Endenergiebedarf</p>,
#  <p> 262,00 kWh/(m²·a)  </p>,
#  <p _ngcontent-sc239="" class="color-grey-500 has-font-75">Energieträger</p>,
#  <p _ngcontent-sc239="">Fernwärme</p>,
#  <p _ngcontent-sc239="" class="color-grey-500 has-font-75">Heizungsart</p>,
#  <p _ngcontent-sc239="">offener Kamin</p>]

# %%
soup.select('sd-cell-row p')[11].get_text() # Haustyp
# Out:
# 'Massivhaus'

# %%
soup.select('p:nth-child(2)')[13].get_text() # Heizungsart
# Out:
# 'F'

# %%
soup.select('sd-cell:nth-child(3) > sd-cell-row > sd-cell-col > p:nth-child(2)')[0].get_text() # Baujahr
# Out:
# '1937'

# %%
text = soup.select('p:nth-child(2)')

pattern = 'id="\w{7}"'
energy = re.findall(pattern, ids_text)

# %%
# %%time
id_houses_soups = []
energy = []
year_built = []
type_of_house = []
heating = []

for i in id:
    # send request
    url = "https://www.immowelt.de/expose/" + i
    response = requests.get(url)
    if response.status_code == 200:
        id_houses_soups.append(url)
    if response.status_code != 200:
        id_houses_soups.append('NaN')
    print(url, response.status_code)
    
    

    # parse & store html
#     soup = BeautifulSoup(response.content, "html.parser")
    
    for m in id_houses_soups:
        try:
            response = requests.get(m)
            soup = BeautifulSoup(response.content, "html.parser")
#         if m != 'NaN':
            
            try:        
                energy.append(soup.select('#js_innerBody > div.content_wrapper > main > app-expose > div.relative.mt-250.ng-star-inserted > div.section-grey-100.relative > app-expose-sections > sd-container > sd-row > sd-col.col.col-400-12.col-8 > div:nth-child(6) > div > app-energy > sd-card > app-energy-equipment > div > sd-cell:nth-child(2) > sd-cell-row > sd-cell-col > p:nth-child(2)')[0].get_text())
                year_built.append(soup.select('sd-cell:nth-child(3) > sd-cell-row > sd-cell-col > p:nth-child(2)')[0].get_text())
                type_of_house.append(soup.select('p:nth-child(2)')[11].get_text())
                heating.append(soup.select('p:nth-child(2)')[13].get_text())
                break
            except:        
                energy.append('NaN')
                year_built.append('NaN')
                type_of_house.append('NaN')
                heating.append('NaN')
                continue
#         if m == 'NaN':
            break
        except:
            energy.append('NaN')
            year_built.append('NaN')
            type_of_house.append('NaN')
            heating.append('NaN')
            continue
        
    # respectful nap:
    wait_time = random.randint(1,2)
    print("I will sleep for " + str(wait_time) + " second/s.")
    sleep(wait_time)
# Out:
# https://www.immowelt.de/expose/29g4z5q 200
# I will sleep for 2 second/s.
# https://www.immowelt.de/expose/29dqw5q 200
# I will sleep for 1 second/s.
# https://www.immowelt.de/expose/29ul65n 200
# I will sleep for 2 second/s.
# https://www.immowelt.de/expose/29us35l 200
# I will sleep for 1 second/s.
# https://www.immowelt.de/expose/292ws5k 200
# I will sleep for 2 second/s.
# https://www.immowelt.de/expose/29uvq5f 200
# I will sleep for 2 second/s.
# https://www.immowelt.de/expose/277e654 200
# I will sleep for 1 second/s.
# https://www.immowelt.de/expose/29h2j5q 200
# I will sleep for 1 second/s.
# https://www.immowelt.de/expose/29pqt5p 200
# I will sleep for 2 second/s.
# https://www.immowelt.de/expose/29tb85p 404
# I will sleep for 2 second/s.
# https://www.immowelt.de/expose/297k75p 200
# I will sleep for 2 second/s.
# https://www.immowelt.de/expose/29nst5m 200
# I will sleep for 2 second/s.
# https://www.immowelt.de/expose/29hhj5m 200
# I will sleep for 1 second/s.
# ...

# %%
print(id_houses_soups)
print(len(id_houses_soups))
print(energy)
print(len(energy))
print(year_built)
print(len(year_built))
print(type_of_house)
print(len(type_of_house))
print(heating)
print(len(heating))
# Out:
# ['https://www.immowelt.de/expose/29g4z5q', 'https://www.immowelt.de/expose/29dqw5q', 'https://www.immowelt.de/expose/29ul65n', 'https://www.immowelt.de/expose/29us35l', 'https://www.immowelt.de/expose/292ws5k', 'https://www.immowelt.de/expose/29uvq5f', 'https://www.immowelt.de/expose/277e654', 'https://www.immowelt.de/expose/29h2j5q', 'https://www.immowelt.de/expose/29pqt5p', 'NaN', 'https://www.immowelt.de/expose/297k75p', 'https://www.immowelt.de/expose/29nst5m', 'https://www.immowelt.de/expose/29hhj5m', 'https://www.immowelt.de/expose/29wdh5m']
# 14
# ['Gas', 'Gas', 'Gas', 'Gas', 'Gas', 'Gas', 'Gas', 'Gas', 'Gas', 'Gas', 'Gas', 'Gas', 'Gas', 'Gas']
# 14
# ['1993', '1993', '1993', '1993', '1993', '1993', '1993', '1993', '1993', '1993', '1993', '1993', '1993', '1993']
# 14
# ['Erdgas H', 'Erdgas H', 'Erdgas H', 'Erdgas H', 'Erdgas H', 'Erdgas H', 'Erdgas H', 'Erdgas H', 'Erdgas H', 'Erdgas H', 'Erdgas H', 'Erdgas H', 'Erdgas H', 'Erdgas H']
# 14
# ...

# %%
soup.select('#js_innerBody > div.content_wrapper > main > app-expose > div.relative.mt-250.ng-star-inserted > div.section-grey-100.relative > app-expose-sections > sd-container > sd-row > sd-col.col.col-400-12.col-8 > div:nth-child(6) > div > app-energy > sd-card > app-energy-equipment > div > sd-cell:nth-child(2) > sd-cell-row > sd-cell-col > p:nth-child(2)')[0]
# Out:
# <p _ngcontent-sc239="">Zentralheizung</p>

# %%
# %%time
id_houses_soups = []
energy = []
year_built = []
type_of_house = []
heating = []
soup = []

for i in id:
    # send request
    url = "https://www.immowelt.de/expose/" + i
    response = requests.get(url)
    if response.status_code == 200:
        id_houses_soups.append(url)
    if response.status_code != 200:
        id_houses_soups.append('NaN')
    print(url, response.status_code)
    
    for m in id_houses_soups:
        if m != 'NaN':
            response = requests.get(m)
            soup.append (response)
        else:
            soup.append('NaN')
# Out:
# https://www.immowelt.de/expose/29g4z5q 200
# https://www.immowelt.de/expose/29dqw5q 200
# https://www.immowelt.de/expose/29ul65n 200
# https://www.immowelt.de/expose/29us35l 200
# https://www.immowelt.de/expose/292ws5k 200
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# ~\anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      71     """
#      72
# ---> 73     return request("get", url, params=params, **kwargs)
#      74
#      75
#
# ~\anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# ...

# %%
soup
# Out:
# [<Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>]

# %%
id_houses_soups
# Out:
# ['https://www.immowelt.de/expose/29g4z5q',
#  'https://www.immowelt.de/expose/29dqw5q',
#  'https://www.immowelt.de/expose/29ul65n',
#  'https://www.immowelt.de/expose/29us35l',
#  'https://www.immowelt.de/expose/292ws5k']
